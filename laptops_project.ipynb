# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4634f888-640f-4dc3-b4f1-70a1230eb6e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4634f888-640f-4dc3-b4f1-70a1230eb6e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving laptop_price.csv to laptop_price (2).csv

# %%
data=pd.read_csv('laptops.csv', encoding='latin-1')
data
# Out:
#      Unnamed: 0 Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # ***Checking for missing values using isnull() :***

# %%
data.isnull()
# Out:
#       Unnamed: 0  Company  Product  TypeName  Inches  ScreenResolution    Cpu  \
# 0          False    False    False     False   False             False  False
# 1          False    False    False     False   False             False  False
# 2          False    False    False     False   False             False  False
# 3          False    False    False     False   False             False  False
# 4          False    False    False     False   False             False  False
# ...          ...      ...      ...       ...     ...               ...    ...
# 1298       False    False    False     False   False             False  False
# 1299       False    False    False     False   False             False  False
# 1300       False    False    False     False   False             False  False
# 1301       False    False    False     False   False             False  False
# 1302       False    False    False     False   False             False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             8
# Product             8
# TypeName            8
# Inches              8
# ScreenResolution    8
# Cpu                 8
# Ram                 8
# Memory              8
# Gpu                 8
# OpSys               8
# Weight              8
# Price_euros         8
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 96

# %% [markdown]
# # ***Filling null values :***
#
# ---
#
#
#
# # 1.   Either fill the null values with some values
# # 2.   Drop such ROWS
# # 3.   Either replace them
#
# ---

# %% [markdown]
# **Filling null values using fillna() :**

# %%
data2=data.fillna(value=0)
data2
# Out:
#      Unnamed: 0 Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
data3=data.fillna(method='bfill')
data3
# Out:
#      Unnamed: 0 Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# ---
#
#
# **Dropping null values using dropna():**
#
#
# ---

# %%
data.dropna()
# Out:
#      Unnamed: 0 Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# ---
#
#
# **Filling null values using replace():**
#
#
#
#
#
# ---

# %%
data5=data.replace(to_replace=np.nan,value=0)
data5.dropna()
# Out:
#      Unnamed: 0 Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # **Data Visualization**

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
L=data5.iloc[:,1]
T=[]
P=[]
for i in range(len(L)):
    if type(L[i])!=str:
        L[i]='Asus'
P=sorted(L)
for i in range(len(P)-1):
    for j in range(len(P)-i-1):
        if P[j]!=P[j+1]:
            T.append(P[j])
        if j==len(P)-2:
            T.append(P[j])
    break
print(T)
print(len(T))
# Out:
# ['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google', 'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft', 'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi']
# 19

# %%
G=list(L)
K=list(data5.iloc[:,12])
I=[]
s=0
Z=[]
for i in range(len(G)):
  if G[i]=='Acer':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Apple':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Asus':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Chuwi':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Dell':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Fujitsu':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Google':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='HP':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I)) 
for i in range(len(G)):
  if G[i]=='Huawei':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='LG':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Lenovo':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='MSI':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Mediacom':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Microsoft':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Razer':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Samsung':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Toshiba':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Vero':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
for i in range(len(G)):
  if G[i]=='Xiaomi':
    I.append(i)
for i in I:
  s+=K[i]
Z.append(s/len(I))
print(Z)
print(len(Z))
# Out:
# [626.7758252427185, 1307.496525423729, 1473.486021126761, 2396.857789473684, 2233.6793814432976, 3280.48774358974, 4325.173911564623, 4013.792923433878, 5068.778634259269, 6119.096862745127, 5630.365463917563, 6482.425993431908, 7542.45658775517, 8605.278334687331, 9668.908675282815, 10713.585605453205, 11436.6243706565, 12518.772571208769, 13597.756277820512]
# 19

# %%
G=data5.iloc[:,4]
G
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1298    14.0
# 1299    13.3
# 1300    14.0
# 1301    15.6
# 1302    15.6
# Name: Inches, Length: 1303, dtype: float64

# %%
plt.bar(T, Z)
plt.xlabel("Brand", fontsize=18)
plt.ylim(500,14000)
plt.ylabel("Average Rating", fontsize=18)
plt.title("Average Rating per Brand", fontsize = 17)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.rcParams["figure.figsize"] = (8,70)
plt.show()

# %%
L1=L=data.iloc[:,6]
T1=data.iloc[:,10]

# %%
plt.scatter(T, Z)
plt.title("PRICE by RAM Size", fontsize=15);
plt.xlabel("RAM Size", fontsize=12);
plt.ylabel("Price", fontsize=12);
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);
plt.rcParams["figure.figsize"] = (8,5)
plt.show()

# %% [markdown]
# # ***Installation de Pyjanitor:***

# %%
pip install pyjanitor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 147 kB 5.2 MB/s
# ...

# %%
import janitor

# %%
janitor.__version__
# Out:
# '0.23.1'

# %% [markdown]
# # ***Data cleaning using pyjanitor:***

# %%
data
# Out:
#      Unnamed: 0 Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
data.clean_names()
# Out:
#      unnamed_0 company                              product  \
# 0            1   Apple                          MacBook Pro
# 1            2   Apple                          Macbook Air
# 2            3      HP                               250 G6
# 3            4   Apple                          MacBook Pro
# 4            5   Apple                          MacBook Pro
# ...        ...     ...                                  ...
# 1298      1316  Lenovo                       Yoga 500-14ISK
# 1299      1317  Lenovo                       Yoga 900-13ISK
# 1300      1318  Lenovo                   IdeaPad 100S-14IBR
# 1301      1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302      1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 typename  inches                            screenresolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# ...

# %%
data.clean_names().remove_empty()
# Out:
#      unnamed_0 company                              product  \
# 0            1   Apple                          MacBook Pro
# 1            2   Apple                          Macbook Air
# 2            3      HP                               250 G6
# 3            4   Apple                          MacBook Pro
# 4            5   Apple                          MacBook Pro
# ...        ...     ...                                  ...
# 1298      1316  Lenovo                       Yoga 500-14ISK
# 1299      1317  Lenovo                       Yoga 900-13ISK
# 1300      1318  Lenovo                   IdeaPad 100S-14IBR
# 1301      1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302      1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 typename  inches                            screenresolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# ...

# %%
data.clean_names().remove_empty().rename_column('company',"brand")
# Out:
#      unnamed_0   brand                              product  \
# 0            1   Apple                          MacBook Pro
# 1            2   Apple                          Macbook Air
# 2            3      HP                               250 G6
# 3            4   Apple                          MacBook Pro
# 4            5   Apple                          MacBook Pro
# ...        ...     ...                                  ...
# 1298      1316  Lenovo                       Yoga 500-14ISK
# 1299      1317  Lenovo                       Yoga 900-13ISK
# 1300      1318  Lenovo                   IdeaPad 100S-14IBR
# 1301      1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302      1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 typename  inches                            screenresolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# ...

# %%
import random
data.clean_names().remove_empty().rename_column('company',"brand").add_column("screen_inches",[random.randint(10,20) for i in range(1303)])
# Out:
#      unnamed_0   brand                              product  \
# 0            1   Apple                          MacBook Pro
# 1            2   Apple                          Macbook Air
# 2            3      HP                               250 G6
# 3            4   Apple                          MacBook Pro
# 4            5   Apple                          MacBook Pro
# ...        ...     ...                                  ...
# 1298      1316  Lenovo                       Yoga 500-14ISK
# 1299      1317  Lenovo                       Yoga 900-13ISK
# 1300      1318  Lenovo                   IdeaPad 100S-14IBR
# 1301      1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302      1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 typename  inches                            screenresolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# ...

# %%
data.clean_names().remove_empty().rename_column('company',"brand").add_column("screen_inches",[random.randint(10,20) for i in range(1303)]).remove_columns(["weight"])
# Out:
#      unnamed_0   brand                              product  \
# 0            1   Apple                          MacBook Pro
# 1            2   Apple                          Macbook Air
# 2            3      HP                               250 G6
# 3            4   Apple                          MacBook Pro
# 4            5   Apple                          MacBook Pro
# ...        ...     ...                                  ...
# 1298      1316  Lenovo                       Yoga 500-14ISK
# 1299      1317  Lenovo                       Yoga 900-13ISK
# 1300      1318  Lenovo                   IdeaPad 100S-14IBR
# 1301      1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302      1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 typename  inches                            screenresolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# ...
